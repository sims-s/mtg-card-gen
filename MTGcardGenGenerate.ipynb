# %% [markdown]
# # How to generate text: using different decoding methods for language generation with Transformers

# %% [markdown]
# ### **Introduction**
#
# In recent years, there has been an increasing interest in open-ended language generation thanks to the rise of large transformer-based language models trained on millions of webpages, such as OpenAI's famous [GPT2 model](https://openai.com/blog/better-language-models/). The results on conditioned open-ended language generation are impressive, e.g. [GPT2 on unicorns](https://openai.com/blog/better-language-models/#samples), [XLNet](https://medium.com/@amanrusia/xlnet-speaks-comparison-to-gpt-2-ea1a4e9ba39e), [Controlled language with CTRL](https://blog.einstein.ai/introducing-a-conditional-transformer-language-model-for-controllable-generation/). Besides the improved transformer architecture and massive unsupervised training data, **better decoding methods** have also played an important role.
#
# This blog post gives a brief overview of different decoding strategies and more importantly shows how *you* can implement them with very little effort using the popular `transformers` library!
#
# All of the following functionalities can be used for **auto-regressive** language generation ([here](http://jalammar.github.io/illustrated-gpt2/) a refresher). In short, *auto-regressive* language generation is based on the assumption that the probability distribution of a word sequence can be decomposed into the product of conditional next word distributions:
# $$ P(w_{1:T} | W_0 ) = \prod_{t=1}^T P(w_{t} | w_{1: t-1}, W_0) \text{ ,with }  w_{1: 0} = \emptyset, $$
#
# and $W_0$ being the initial *context* word sequence. The length $T$ of the word sequence is usually determined *on-the-fly* and corresponds to the timestep $t=T$ the EOS token is generated from $P(w_{t} | w_{1: t-1}, W_{0})$.
#
#
# Auto-regressive language generation is now available for `GPT2`, `XLNet`, `OpenAi-GPT`, `CTRL`, `TransfoXL`, `XLM`, `Bart`, `T5` in both PyTorch and Tensorflow >= 2.0!
#
# We will give a tour of the currently most prominent decoding methods, mainly *Greedy search*, *Beam search*, *Top-K sampling* and *Top-p sampling*.

# %% [markdown]
# Let's quickly install transformers and load the model. We will use GPT2 in Tensorflow 2.1 for demonstration, but the API is 1-to-1 the same for PyTorch.

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for transformers (PEP 517) ... done

# %%
# !nvidia-smi
# Out:
# Thu Jan 21 04:27:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_path = './drive/My Drive/models/mtg_card_gen/checkpoint-200/'
# model_path = 'gpt2-large

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import os
import json
tokenizer = AutoTokenizer.from_pretrained(model_path)

# add the EOS token as PAD token to avoid warnings
model = AutoModelForCausalLM.from_pretrained(model_path, pad_token_id=tokenizer.eos_token_id).eval()

# %%
device = torch.device('cuda')

# %%
model = model.to(device)

# %%
results = {}

# %%
def print_and_add_to_results(output, key, add=True):
  if not key in results:
    results[key] = []
  str_out = tokenizer.decode(output, skip_special_tokens=True)
  print(str_out)
  if add:
    results[key].append(str_out)

# %% [markdown]
# ### **Greedy Search**
# * Greedy search doesn't work very well, outputs aren't great
# * Decent amount of repitition
# * Wrong Structure

# %%
max_length = 256

# %%
# encode context the generation is conditioned on
prompt = "Flamebreathing Pidgeon"
input_ids = tokenizer.encode(prompt, return_tensors='pt', add_special_tokens=False).to(device)

# %%
# generate text until the output length (which includes the context length) reaches 50
greedy_output = model.generate(input_ids, max_length=135)

print_and_add_to_results(greedy_output[0], 'greedy')
# Out:
# Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common| Flying line_break When Flamebreathing Pidgeon dies, create a 1/1 green Bird creature token with flying.| 2| 2| None| "The birds are the only thing that can stop the dragon." line_break —Gerrard of the Kessig end_of_card Gerrard of the Kessig| Creature — Bird| {2}{G}| common| Flying line_break When Gerrard of the Kessig dies, create a 1/1 green Bird creature token with flying.| 2| 2

# %%
# activate beam search and early_stopping
beam_outputs = model.generate(
    input_ids,  
    max_length=84, 
    num_beams=5, 
    early_stopping=True,
    num_return_sequences=5, 
)

for i, beam_output in enumerate(beam_outputs):
  print_and_add_to_results(beam_output, 'beam', add=True)
# Out:
# Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common| Flying line_break When Flamebreathing Pidgeon enters the battlefield, create a 1/1 green Bird creature token with flying.| 2| 2| None| None end_of_card Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common|
# Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common| Flying line_break When Flamebreathing Pidgeon enters the battlefield, create a 1/1 green Bird creature token with flying.| 2| 2| None| None end_of_card Flamebreathing Salamander| Creature — Salamander| {2}{G}| common|
# Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common| Flying line_break When Flamebreathing Pidgeon enters the battlefield, create a 1/1 green Bird creature token with flying.| 2| 2| None| None end_of_card Flamebreathing Salamander| Creature — Salamander| {3}{G}| common|
# Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common| Flying line_break When Flamebreathing Pidgeon enters the battlefield, create a 1/1 green Bird creature token with flying.| 2| 2| None| None end_of_card Flamebreathing Salamander| Creature — Salamander| {1}{G}| common|
# Flamebreathing Pidgeon| Creature — Bird| {2}{G}| common| Flying line_break When Flamebreathing Pidgeon enters the battlefield, create a 1/1 green Bird creature token with flying.| 2| 2| None| None end_of_card Flamebreathing Salamander| Creature — Salamander| {2}{G}| uncommon|

# %% [markdown]
# ### **Sampling**
#
# In its most basic form, sampling means randomly picking the next word $w_t$ according to its conditional probability distribution:
#
# $$w_t \sim P(w|w_{1:t-1})$$
#
# Taking the example from above, the following graphic visualizes language generation when sampling.
#
# ![vanilla_sampling](https://raw.githubusercontent.com/patrickvonplaten/scientific_images/master/sampling_search.png)
#
# It becomes obvious that language generation using sampling is not *deterministic* anymore. The word
# $\text{"car"}$ is sampled from the conditioned probability distribution $P(w | \text{"The"})$, followed by sampling $\text{"drives"}$ from $P(w | \text{"The"}, \text{"car"})$.
#
# In `transformers`, we set `do_sample=True` and deactivate *Top-K* sampling (more on this later) via `top_k=0`. In the following, we will fix `random_seed=0` for illustration purposes. Feel free to change the `random_seed` to play around with the model.

# %%
# activate sampling and deactivate top_k by setting top_k sampling to 0
sample_outputs = model.generate(
    input_ids, 
    do_sample=True, 
    max_length=128, 
    top_k=0,
    num_return_sequences=5,
)

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print_and_add_to_results(sample_output, 'sample_base', True)
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# Flamebreathing Pidgeon| Creature — Bird Soldier| {4}{G}| common| Flying line_break Flash (You may cast this spell any time you could cast an instant.)| 3| 1| None| Every sparrow that rises above Petalwood yawns and withers within a thousand years. end_of_card Melsheim Madness| Enchantment — Aura| {3}{U}| common| Enchant creature line_break Enchanted creature gets +2/+1 and has flying.| None| None| None| "All metals, vermin fed on endogenously it
# Flamebreathing Pidgeon| Creature — Snake| {4}{W}| common| Choose one — line_break • Tap and other cards you control: Suncloaks gain that many life. line_break • Tap and other cards you control: Suncloaks gain that many life.| 4| 4| None| None end_of_card Slobbe Mutilator| Creature — Horror| {2}{W}| common| Change Slobbe Mutilator's power and toughness as you cast this spell. (Damage and effects that say "destroy" don't destroy it.)
# Flamebreathing Pidgeon| Creature — Ethereal Shapeshifter| {3}{W}| rare| When Flamebreathing Pidgeon enters the battlefield, return target creature to the battlefield under its owner's control.| 4| 5| None| None end_of_card Flamebreathing Squirrel| Creature — Plant| {3}{W}| uncommon| Flying line_break When Flamebreathing Squirrel enters the battlefield, return target creature to the battlefield under its owner's control.| 3| 2| None| None end_of_card Gloomblown Air| Sorcery
# Flamebreathing Pidgeon| Creature — Beast| {2}{R}| uncommon| Flash (You may cast this spell any time you could cast an instant.) line_break Whenever a creature you control attacks, tap any number of target artifact or creature you control.| 2| 2| None| "Into their hearts one always dies and dreams are buried." end_of_card Armored Drooling| Creature — Drake| {3}{R}| common| Flying line_break Menace (This creature can't be blocked except by artifact creatures and/or black creatures.)| 2| 3|
# Flamebreathing Pidgeon| Creature — Plant Artificer| {3}{U}| uncommon| Flash line_break {X}, {T}: Return spells from your graveyard to the battlefield tapped. Activate this ability only during the declare attackers step.| 3| 1| None| Hippo fears no change in their destinies. end_of_card Mister Bequeathed| Creature — Plant Pidgeon| {2}{U}| common| Flash line_break {1}{U}, {T}: Return target artifact card from your graveyard to your hand. Activate this ability only during

# %% [markdown]
# A trick is to make the distribution $P(w|w_{1:t-1})$ sharper (increasing the likelihood of high probability words and decreasing the likelihood of low probability words) by lowering the so-called `temperature` of the [softmax](https://en.wikipedia.org/wiki/Softmax_function#Smooth_arg_max).
#
# ![top_p_sampling](https://github.com/patrickvonplaten/scientific_images/blob/master/sampling_search_with_temp.png?raw=true)
#
# Let's see how we can cool down the distribution in the library by setting `temperature=0.7`:

# %%
# use temperature to decrease the sensitivity to low probability candidates
sample_outputs = model.generate(
    input_ids, 
    do_sample=True, 
    max_length=128, 
    top_k=0, 
    temperature=0.7,
    num_return_sequences=5
)

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print_and_add_to_results(sample_output, 'temp_.7', True)
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# Flamebreathing Pidgeon| Creature — Fungus| {4}{W}{W}| common| Sacrifice a number of creature cards from an opponent's graveyard: Ragebreathing Pidgeon gets +2/+2 until end of turn.| 4| 3| None| "This is the time to draw my sword." end_of_card Fungus Whiptail| Creature — Wurm| {5}{W}| common| {T}: Add {W} or {U}.| 5| 4| None| "Those who dwell in it will be free to adapt to
# Flamebreathing Pidgeon| Creature — Peacemaker| {B}| uncommon| Cumulative upkeep {2} (At the beginning of your upkeep, put an age counter on this permanent, then sacrifice it unless you pay its upkeep cost for each age counter on it.) line_break When Cumulative upkeep is paid, Cumulative upkeep deals X damage to you, where X is Cumulative upkeep's power.| 1| 1| None| "The sun is shining with all of us." end_of_card Eternal Destiny| Enchantment| {2}{W}{U}| rare| At
# Flamebreathing Pidgeon| Creature — Elemental| {3}{R}| common| Flying line_break {R}: Flamebreathing Pidgeon gains deathtouch until end of turn.| 2| 2| None| None end_of_card Firestorm Bolas| Creature — Elemental| {1}{R}| common| Flying line_break {R}: Firestorm Bolas gains haste until end of turn.| 1| 1| None| None end_of_card Furygrinder| Creature — Elemental| {4}{R}| uncommon| Haste line_break Whenever
# Flamebreathing Pidgeon| Creature — Human Wizard| {1}{U}| common| Haste line_break When Flamebreathing Pidgeon enters the battlefield, you may put a creature card with converted mana cost 3 or less from your graveyard onto the battlefield.| 1| 3| None| "The art is obvious. That's why you're here. You'll be proven right in the end." end_of_card Goblin Goblin| Creature — Goblin| {2}{U}| common| {T}, Sacrifice another creature: Draw a card.| 1| 1| None|
# Flamebreathing Pidgeon| Creature — Dragon| {2}{U}{U}| rare| Flying line_break Whenever a source an opponent controls deals damage to a player, that player discards a card at random.| 2| 2| None| "This is the fate of the dragons." line_break —Gerrard of the Sands end_of_card Grizzled Stag| Creature — Human Wizard| {2}{U}| uncommon| Flying line_break Whenever a source an opponent controls deals damage to a player, that player discards a card at random.| 2|

# %% [markdown]
# ### **Top-K Sampling**
#
# [Fan et. al (2018)](https://arxiv.org/pdf/1805.04833.pdf) introduced a simple, but very powerful sampling scheme, called ***Top-K*** sampling. In *Top-K* sampling, the *K* most likely next words are filtered and the probability mass is redistributed among only those *K* next words.
# GPT2 adopted this sampling scheme, which was one of the reasons for its success in story generation.
#
# We extend the range of words used for both sampling steps in the example above from 3 words to 10 words to better illustrate *Top-K* sampling.
#
# ![top_k_sampling](https://raw.githubusercontent.com/patrickvonplaten/scientific_images/master/top_k_sampling.png)
#
# Having set $K = 6$, in both sampling steps we limit our sampling pool to 6 words. While the 6 most likely words, defined as $V_{\text{top-K}}$ encompass only *ca.* two-thirds of the whole probability mass in the first step, it includes almost all of the probability mass in the second step. Nevertheless, we see that it successfully eliminates the rather weird candidates $\text{"not", "the", "small", "told"}$
# in the second sampling step.
#
#
# Let's see how *Top-K* can be used in the library by setting `top_k=50`:

# %%
# set top_k to 50
torch.manual_seed(0)
sample_outputs = model.generate(
    input_ids, 
    do_sample=True, 
    max_length=max_length, 
    top_k=50,
    num_return_sequences=5
)

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print_and_add_to_results(sample_output, 'top_k_50', True)
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# Flamebreathing Pidgeon| Creature — Bird| {6}{U}| common| Protection from red| 3| 3| None| "I will send that brood to be consumed with Fire for eternity, and I will be the one to bring it home. It will do the rest." end_of_card Flamebreathing Pidgeon| Instant| {1}{U}| common| Flamebreathing Pidgeon deals 3 damage to any target.| None| None| None| "Fire is a weapon whose power cannot be measured. If you dare to wield it against me, you will be incinerated!" line_break —Alena, Selesnya initiate end_of_card Herald of Justice| Creature — Construct| {6}| common| Hexproof line_break {4}, Sacrifice Herald of Justice: Draw a card.| 6| 5| None| "If you love your work, you must earn it. Your deeds shall triumph, not dishonor." line_break —Thalia, Selesnya initiate end_of_card Kalas, God of the Damned| Legendary Creature — God| {4}{U}{U}| mythic| When
# Flamebreathing Pidgeon| Enchantment| {5}{W}| rare| Whenever an instant or sorcery spell an opponent controls causes you to gain life, you may put a +1/+1 counter on Cursebrute. If you do, Cursebrute deals damage equal to the number of +1/+1 counters put on Cursebrute to you equal to your life total.| None| None| None| "Tales, stories, death, every kind of pain. I won't leave behind such a burden anymore." end_of_card Destructor Spike| Instant| {1}{U}| uncommon| Destroy target creature and destroy all nonland permanents.| None| None| None| "The best is right there, just off the top where they'll fall." line_break —Teyla, Gruul hunter end_of_card Elendra, Empyreal Archfiend| Legendary Artifact Creature — Human Rebel| {U}| rare| Flying line_break When Elendra, Empyreal Archfiend enters the battlefield, create a 3/3 green Human Rebel creature token.| 2| 1| None| "Life is nothing compared to the force which conquers." end_
# Flamebreathing Pidgeon| Creature — Insect Beast| {2}{W}{W}| common| None| 2| 2| None| A powerful poisonous beast with a grudge on its soul, and only a fool would allow a snake to do so. end_of_card Kor Wort| Creature — Insect| {W}| common| Defender| 2| 2| None| The kor are known for their venomous bite. In some places, their throats are as deep as your fingers. end_of_card Leechwing Snake| Creature — Snake| {W}| common| None| 3| 4| None| There's just one thing that kills many in the Krosa wilds at random—the venom on the tongue. end_of_card Lightning Spider| Creature — Spider| {3}{U}{U}| uncommon| Kicker {3}{U} (You may pay an additional {3}{U} as you cast this spell.) line_break Flashback {4}{U}{U} (You may cast this card from your graveyard for its flashback cost. Then exile it.)| 1| 4| None| "Those who are strong will survive the winter
# Flamebreathing Pidgeon| Creature — Frog| {2}{W}{W}| rare| Bloodrush—Whenever this creature deals combat damage to a player, that player may draw a card. line_break {2}, Discard a cards: Draw a card.| 1| 2| None| They look at their foes with keen eyes. end_of_card Cocoonpike Drake| Creature — Eel| {2}{W}| uncommon| Flying line_break Whenever Cursedpike Drake deals damage to a player, that player loses 2 life and you gain 2 life.| 2| 2| None| None end_of_card Flameblood Boar| Creature — Spirit| {4}{W}{W}| uncommon| Flash line_break {W}{W}, Discard a card: Draw a card.| 3| 3| None| Their hunger is only as strong as a strong wind. end_of_card Glacial Cliffs of Eternity| Sorcery| {4}{W}{W}| rare| Reveal the top five cards of your library. Put one of them into your hand and the rest into your graveyard.| None| None| None| The cliffs are
# Flamebreathing Pidgeon| Creature — Boar| {R}| common| {G}, Discard a card: Destroy target permanent. Activate this ability only any time you could cast a sorcery.| 1| 1| None| "Why would it hurt me to do this for pleasure when it is my duty?" line_break —Tolarian, *Savage Feast*, volume II, page 7-9 end_of_card Horde of Mizzium| Sorcery| {4}{R}{R}| common| Destroy all lands that don't have creatures you control.| None| None| None| Though they were all created by the Lord, each line of the Lord's will was shaped from their own will. end_of_card Nissa Revane| Enchantment| {2}{R}| common| Destroy target blue nonland.| None| None| None| "When I was a child, Chandra chose one to serve within the line of loyalty. I chose Nissa for that honor." line_break —*The Unbroken* end_of_card Orisan Zealot| Creature — Human Soldier| {4}{R}{R}| uncommon| {R}, Disc

# %% [markdown]
# One concern though with *Top-K* sampling is that it does not dynamically adapt the number of words that are filtered from the next word probability distribution $P(w|w_{1:t-1})$.

# %% [markdown]
# ### **Top-p (nucleus) sampling**
#
# Instead of sampling only from the most likely *K* words, in *Top-p* sampling chooses from the smallest possible set of words whose cumulative probability exceeds the probability *p*. The probability mass is then redistributed among this set of words.
# ![top_p_sampling](https://github.com/patrickvonplaten/scientific_images/blob/master/top_p_sampling.png?raw=true)

# %%
torch.manual_seed(0)

# deactivate top_k sampling and sample only from 92% most likely words
sample_outputs = model.generate(
    input_ids, 
    do_sample=True, 
    max_length=max_length, 
    top_p=0.92, 
    top_k=0,
    num_return_sequences=5
)

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print_and_add_to_results(sample_output, 'top_p_.92', True)
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# Flamebreathing Pidgeon| Creature — Bird| {6}{U}| common| Protection from red| 3| 3| None| "I will fly that way. If you speak of it, you'll agree that it's a blessing." line_break —Craska —Flamebreathing Pidgeon end_of_card Gill Strider| Creature — Insect| {4}{U}| common| Haste line_break Each creature you control with hexproof gets +1/+1 and has menace.| 4| 3| None| "May you protect the Gardens of Plenty." end_of_card Ice Climb| Enchantment| {3}{U}{U}| rare| Ice Climb enters the battlefield with two -1/-1 counters on it for each card in your hand. line_break Threshold — Ice Climb enters the battlefield with three -1/-1 counters on it for each card in your hand.| None| None| None| She taunted its inhabitants, saying, "Thumb your fingernails and lift your strength to the world of armaments." end_of_card Implant| Instant| {2}{U}| common| Target player loses 1
# Flamebreathing Pidgeon| Creature — Imp| {3}{G}{W}| uncommon| Haste line_break When Cursebreathing Pidgeon dies, create a 1/1 white Imp creature token with haste. line_break Whenever Cursebreathing Pidgeon attacks alone, create a 4/4 black Imp creature token with haste.| 5| 5| None| None end_of_card Ghost Slide| Sorcery| {4}{G}| common| Echo target spell, permanent, or ability you control. Put the rest on the bottom of your library in a random order. line_break [−2]: Exile target artifact or enchantment card from your graveyard. If it's a creature card, tap that creature.| None| None| None| None end_of_card Guilt| Sorcery| {3}{G}| uncommon| Return target creature card from your graveyard to your hand. line_break Draw a card.| None| None| None| He imagined a cage, reduced to something monstrous. The thought didn't faze him; just vanished into a few minutes. end_of_card One Thousand Lives| Sorcery| {2}{G}{W}| common
# Flamebreathing Pidgeon| Creature — Insect Beast| {2}{W}{W}| common| None| 2| 2| None| A powerful poisonous beast with hunger, thirst, and neither back nor forth. end_of_card Flamebreathing Pirate| Creature — Frog| {3}{U}| common| None| 4| 4| None| The fisherman deftly plucks alec during their wine days and reveals the spices hidden under bark, hoping it will fuel him again. end_of_card Firecloak Caller| Creature — Elf Warrior| {1}{W}{W}| rare| First strike line_break Whenever Firecloak Caller attacks, create a 3/3 green Angel creature token with vigilance. line_break Firecloak Caller gets +1/+0 for each red and green creature card in your graveyard.| 2| 2| None| "My third firebolt, tasty; worthy." end_of_card Gloombeast Selkie| Creature — Nightmare Cat| {4}{U}{U}| uncommon| None| 2| 4| None| She stills her army numbering numbers of hundreds, when she reaches Maren, the vizier of fire. end
# Flamebreathing Pidgeon| Creature — Frog| {2}{W}{W}| rare| Bloodrush (This creature can't be blocked except by creatures with flying or reach.) line_break Burst (Whenever this creature attacks, it gets +1/+0 until end of turn.)| 1| 3| None| The word cursed in Ennistus is the language of ascension, defined by ignorance or fallibility. end_of_card Bospex| Artifact Creature — Golem| {4}{W}| common| Flying line_break Bushpex can't be blocked except by creatures with flying or reach.| 4| 4| None| Before the war, 'Azorius' burned many monuments, including hundreds of civil wars and foul, binding spells. end_of_card Coral Reef Bottle| Artifact Creature — Bottle| {2}{W}| rare| {1}, Sacrifice Coral Reef Bottle: Return target permanent card from your graveyard to your hand. Activate this ability only any time you could cast a sorcery.| 2| 2| None| "Ongoing saltwater flows like a storm to tide the oceans." line_break —Kalan, Auriok captain end_of_card D
# Flamebreathing Pidgeon| Creature — Nightmare Dinosaur| {R}| common| {G}, Discard a card: Destroy target permanent. Activate this ability only any time you could cast a sorcery.| 1| 1| None| "Why would it hurt me to do this?" line_break —Khaos, nomad ranger end_of_card Grinning Blight| Instant| {3}{G}| uncommon| Choose one — line_break • Search your library for a Plains card, reveal that card, and put it into your hand. line_break • Scry 1. line_break • Search your library for a Swamp card, reveal that card, and put it into your hand.| None| None| None| None end_of_card Human Fatigue| Instant| {1}{U}{U}| common| Discard three cards: Scry 1. line_break • Search your library for a land card, put it into your hand, then shuffle your library.| None| None| None| "Welcome to Pevoch!" end_of_card Quill of Grace| Sorcery| {1}{B}| uncommon| If an opponent has fewer cards in hand

# %% [markdown]
# Great, that sounds like it could have been written by a human. Well, maybe not quite yet.
#
# While in theory, *Top-p* seems more elegant than *Top-K*, both methods work  well in practice. *Top-p* can also be used in combination with *Top-K*, which can avoid very low ranked words while allowing for some dynamic selection.
#
# Finally, to get multiple independently sampled outputs, we can *again* set the parameter `num_return_sequences > 1`:

# %%
torch.manual_seed(0)
# set top_k = 50 and set top_p = 0.95 and num_return_sequences = 3
sample_outputs = model.generate(
    input_ids,
    do_sample=True, 
    max_length=max_length, 
    top_k=50, 
    top_p=0.95, 
    num_return_sequences=5
)

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print_and_add_to_results(sample_output, 'top_p_.92_k_50', True)
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# Flamebreathing Pidgeon| Creature — Bird| {6}{U}| common| Protection from red| 3| 3| None| "I will send that brood to be consumed with the venom. Its heart will rise before the blood-grinding poison. It will do the rest." line_break —Aurelia, elder end_of_card Sporeclutch| Instant| {1}{U}| common| Destroy target blue or green creature. It gains indestructible until end of turn.| None| None| None| "In his place is the fire of passion." line_break —Leonin Tarlov end_of_card Sporecrasher| Creature — Bird| {3}{U}| uncommon| Flying line_break {2}{U}: Target creature gets -1/-1 until end of turn.| 2| 4| None| "The wings of sporecrasher sting as hard as steel and are as deadly as their blood." line_break —Leonin Tarlov end_of_card Sporecrasher's Blade| Creature — Bird| {3}{U}| uncommon| Flying line_break {4}{U}: Target creature gets -3
# Flamebreathing Pidgeon| Creature — Imp| {3}{G}{W}| uncommon| Haste line_break When Cursebreathing Pidgeon dies, create a 1/1 white Imp creature token with haste. line_break Whenever Cursebreathing Pidgeon attacks alone, create a 4/4 black Imp creature token with haste.| 5| 5| None| None end_of_card Tales of the Kite Beetle| Enchantment| {2}{U}{B}| rare| When Tales of the Kite Beetle enters the battlefield, exile all artifacts and enchantments you control. You may cast spells from the top of your library that target this card unless you pay {U}.| None| None| None| None end_of_card Tales of the Temptation Beetle| Enchantment| {3}{U}{C}| rare| When Tales of the Temptation Beetle enters the battlefield, exile all artifacts and enchantments you control. You may cast spells from the top of your library unless you pay {C}.| None| None| None| None end_of_card Tales of the Wurm| Creature — Wurm| {2}{U}{
# Flamebreathing Pidgeon| Creature — Insect Beast| {2}{W}{W}| common| None| 2| 2| None| A powerful poisonous beast with a grudge on its soul, and only a fool would allow a snake to do so. end_of_card Kor Wort| Creature — Insect| {W}| common| None| 2| 2| None| The kor are known for their venomous, hungering tongue, and their thirst for blood. Kor Wort feeds on both. end_of_card Kyrela's Fury| Instant| {W}| common| Destroy target nonland permanent.| None| None| None| "Blood can help." line_break —Kyrela end_of_card Kyrela's Recluse| Enchantment| {1}{W}{W}| rare| When Kyrela's Recluse enters the battlefield, each opponent loses 1 life and you gain 1 life. line_break Whenever an opponent loses life or becomes blocked, Kyrela's Recluse deals that much damage to that player or planeswalker's controller.| None| None| None| None end_of_card Mizz
# Flamebreathing Pidgeon| Creature — Frog| {2}{W}{W}| rare| Bloodrush (This creature can't be blocked except by creatures with flying or reach.) line_break {W}: Shuffle Flamebreathing Pidgeon. Activate this ability only during your upkeep and only once each turn.| 1| 2| None| Its tail twirls with a gentle touch as it crawls about the camp and feeds. end_of_card Korin's Gaze| Sorcery| {3}{U}{U}| common| Destroy target artifact.| None| None| None| It follows a path from a young girl who was a thief to a rich, wealthy father, then to a wealthy brother. end_of_card Kolaghan, Stormcaller of Graft| Legendary Creature — Kor| {2}{U}{U}{U}| rare| Flying line_break Korin's Gaze enters the battlefield with X +1/+1 counters on it, where X is Tolaghan's total power.| 1| 2| None| Like it has always been, the winds in its wake threaten to bring ruin to its subjects. end_of_card Knight-
# Flamebreathing Pidgeon| Creature — Boar| {R}| common| {G}, Discard a card: Destroy target permanent. Activate this ability only any time you could cast a sorcery.| 1| 1| None| "Why would it hurt me to do this?" line_break —Kha'Zix end_of_card Feral Gloom| Instant| {1}{G}| common| Target player discards three cards.| None| None| None| Its victims are the only thing left of their victims. end_of_card Ghoulfire| Sorcery| {G}{G}| common| Destroy target artifact, enchantment, land, or planeswalker.| None| None| None| Bloodthirsty mages have hunted down and enslaved an entire clan of Ghouls. end_of_card Krovikan Scavenger| Creature — Human Soldier| {2}{G}{G}| uncommon| Lifelink (Damage dealt by this creature also causes you to gain that much life.) line_break Morph {2}{G}{G} (You may cast this card face down as a 2/2 creature for {3}. Turn it face up any time for its morph

# %%
def save_json(path, to_save):
  with open(path, 'w', encoding='utf-8') as f:
    json.dump(to_save, f)

# %%
save_path = './drive/My Drive/models/mtg_card_gen/outputs/'
specific_save_path = save_path + prompt + '.json'

# %%
save_json(specific_save_path, results)
